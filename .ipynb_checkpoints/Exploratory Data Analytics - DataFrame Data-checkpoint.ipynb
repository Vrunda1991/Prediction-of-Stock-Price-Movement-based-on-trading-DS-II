# %%
import numpy as np
import pandas as pd

# %%
data1 = pd.read_csv("./Datasets/DataFrame.csv")

# %%
data1.sample(10)
# Out:
#         Type      Date   Time      open      high       low     close  \
# 4437   NIFTY  20210118  13:58  14352.20  14356.55  14351.45  14352.60
# 10729  NIFTY  20210211  11:46  15140.20  15150.55  15140.20  15146.85
# 1780   NIFTY  20210107  13:46  14177.20  14186.15  14177.20  14186.15
# 17961  NIFTY  20210312  10:24  15285.35  15285.35  15277.70  15277.70
# 4861   NIFTY  20210119  14:44  14532.80  14534.60  14530.20  14532.80
# 11639  NIFTY  20210215  14:20  15283.10  15284.50  15277.05  15284.50
# 9739   NIFTY  20210208  14:10  15143.50  15148.80  15143.45  15148.00
# 15300  NIFTY  20210302  10:09  14916.60  14922.25  14914.50  14918.45
# 11310  NIFTY  20210212  15:09  15146.40  15148.35  15143.75  15146.50
# 8135   NIFTY  20210202  12:36  14564.50  14574.10  14563.90  14572.55
#
#        Unnamed: 7
# 4437          NaN
# 10729         NaN
# 1780          NaN
# 17961         NaN
# 4861          NaN
# 11639         NaN
# 9739          NaN
# 15300         NaN
# 11310         NaN
# 8135          NaN

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22805 entries, 0 to 22804
# Data columns (total 8 columns):
# Type          22805 non-null object
# Date          22805 non-null int64
# Time          22805 non-null object
# open          22805 non-null float64
# high          22805 non-null float64
# low           22805 non-null float64
# close         22805 non-null float64
# Unnamed: 7    0 non-null float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 1.4+ MB

# %%
data1.shape
# Out:
# (22805, 8)

# %%
data1.columns
# Out:
# Index(['Type', 'Time', 'open', 'high', 'low', 'close'], dtype='object')

# %%
data1.nunique(axis=0)
# Out:
# Type         1
# Time       457
# open     14944
# high     15007
# low      15101
# close    15036
# dtype: int64

# %%
data1.isnull().sum()
# Out:
# Type              0
# Date              0
# Time              0
# open              0
# high              0
# low               0
# close             0
# Unnamed: 7    22805
# dtype: int64

# %%
data1 = data1.drop(['Unnamed: 7'], axis=1)

# %%
data1 = data1.drop(['Date'], axis=1)

# %%
data1.describe()
# Out:
#                open          high           low         close
# count  22805.000000  22805.000000  22805.000000  22805.000000
# mean   14703.322396  14707.486481  14699.102201  14703.260816
# std      391.377498    391.265231    391.551643    391.366248
# min    13604.750000  13614.400000  13596.750000  13602.800000
# 25%    14462.250000  14465.950000  14458.050000  14461.950000
# 50%    14739.500000  14743.000000  14735.850000  14739.450000
# 75%    15037.000000  15041.250000  15032.500000  15036.850000
# max    15429.500000  15431.750000  15427.900000  15430.200000

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.boxplot(data1.open);

# %%
sns.boxplot(data1.close);

# %%
sns.boxplot(data1.high);

# %%
sns.boxplot(data1.low);

# %% [markdown]
# # Analyzing relationships between variables

# %% [markdown]
# ### 1. Correlation Matrix

# %%
corr = data1.corr()# plot the heatmap
sns.heatmap(corr, annot=True);

# %% [markdown]
# ### 2. Scatterplot

# %%
sns.scatterplot('open', 'close', data=data1);
sns.scatterplot('high', 'low', data=data1);

# %%
sns.pairplot(data1)

# %% [markdown]
# # Distribution of the data

# %%
sns.distplot(data1.open);

# %%
sns.distplot(data1.close);

# %%
sns.distplot(data1.high);

# %%
sns.distplot(data1.low);

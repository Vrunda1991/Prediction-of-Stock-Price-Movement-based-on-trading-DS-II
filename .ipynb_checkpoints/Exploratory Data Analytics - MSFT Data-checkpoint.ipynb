# %%
import numpy as np
import pandas as pd

# %%
data2 = pd.read_csv("./Datasets/MSFT.csv")

# %%
data2.sample(10)
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 3583  2000-05-16  34.781250  35.312500  34.531250  34.750000  22.071487
# 6041  2010-02-25  28.270000  28.650000  28.020000  28.600000  22.327806
# 4994  2005-12-27  26.680000  26.850000  26.450001  26.459999  19.183878
# 3487  1999-12-29  58.468750  59.187500  58.406250  58.968750  37.454044
# 8104  2018-05-07  95.169998  96.709999  95.099998  96.220001  92.447807
# 6496  2011-12-13  25.750000  26.100000  25.650000  25.760000  20.976807
# 922   1989-11-02   0.561632   0.561632   0.527778   0.529514   0.336321
# 8018  2018-01-02  86.129997  86.309998  85.500000  85.949997  82.194328
# 2217  1994-12-16   3.976563   4.015625   3.950195   3.960938   2.515792
# 6913  2013-08-13  32.509998  32.549999  32.209999  32.230000  27.595020
#
#          Volume
# 3583   48410600
# 6041   48735300
# 4994   37819000
# 3487   17449200
# 8104   24242000
# 6496   54581100
# 922   226051200
# 8018   22483800
# 2217   54020800
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8857 entries, 0 to 8856
# Data columns (total 7 columns):
# Date         8857 non-null object
# Open         8857 non-null float64
# High         8857 non-null float64
# Low          8857 non-null float64
# Close        8857 non-null float64
# Adj Close    8857 non-null float64
# Volume       8857 non-null int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 484.4+ KB

# %%
data2.shape
# Out:
# (8857, 7)

# %%
data2.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
data2.nunique(axis=0)
# Out:
# Date         8857
# Open         4993
# High         4943
# Low          4959
# Close        5149
# Adj Close    6762
# Volume       8677
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
data2 = data2.drop(['Date'], axis=1)

# %%
data2.describe()
# Ask a question, why the volume values are coming in this format?
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  8857.000000  8857.000000  8857.000000  8857.000000  8857.000000
# mean     34.831233    35.209355    34.449657    34.840895    29.886536
# std      44.060163    44.513443    43.597704    44.080986    44.195101
# min       0.088542     0.092014     0.088542     0.090278     0.057340
# 25%       3.843750     3.875000     3.812500     3.851563     2.446323
# 50%      26.590000    26.879999    26.290001    26.590000    18.686628
# 75%      36.730000    37.000000    36.110001    36.660000    27.218300
# max     261.660004   263.190002   260.170013   261.970001   261.970001
#
#              Volume
# count  8.857000e+03
# mean   5.953411e+07
# std    3.858121e+07
# min    2.304000e+06
# 25%    3.559720e+07
# 50%    5.269680e+07
# 75%    7.339520e+07
# max    1.031789e+09

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.boxplot(data2.Open);

# %%
sns.boxplot(data2.Close);

# %%
sns.boxplot(data2.High);

# %%
sns.boxplot(data2.Low);

# %%
data2 = data2.rename(columns={'Adj Close': 'Adj_Close'})

# %%
sns.boxplot(data2.Adj_Close);

# %%
sns.boxplot(data2.Volume);

# %% [markdown]
# # Analyzing relationships between variables

# %% [markdown]
# ### 1. Correlation Matrix

# %%
corr = data2.corr()# plot the heatmap
sns.heatmap(corr, annot=True);

# %% [markdown]
# ### 2. Scatterplot

# %%
sns.scatterplot('Open', 'Volume', data=data2);
sns.scatterplot('Adj_Close', 'Volume', data=data2);

# %%
sns.pairplot(data2)

# %% [markdown]
# # Distribution of the data

# %%
sns.distplot(data2.Open);

# %%
sns.distplot(data2.High);

# %%
sns.distplot(data2.Low);

# %%
sns.distplot(data2.Close);

# %%
sns.distplot(data2.Adj_Close);

# %%
sns.distplot(data2.Volume);
